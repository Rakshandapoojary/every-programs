# %%
#Importing the necessary Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
#Importing the required dataset
cars_df = pd.read_csv("C:/Users/Admin/Desktop/Cars93.csv")
cars_df
# Out:
#     Id Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0    1        Acura  Integra    Small       12.9   15.9       18.8        25
# 1    2        Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2    3         Audi       90  Compact       25.9   29.1       32.3        20
# 3    4         Audi      100  Midsize       30.8   37.7       44.6        19
# 4    5          BMW     535i  Midsize       23.7   30.0       36.2        22
# ..  ..          ...      ...      ...        ...    ...        ...       ...
# 88  89   Volkswagen  Eurovan      Van       16.6   19.7       22.7        17
# 89  90   Volkswagen   Passat  Compact       17.6   20.0       22.4        21
# 90  91   Volkswagen  Corrado   Sporty       22.9   23.3       23.7        18
# 91  92        Volvo      240  Compact       21.8   22.7       23.5        21
# 92  93        Volvo      850  Midsize       24.8   26.7       28.5        20
#
#     MPG.highway             AirBags  ... Passengers Length  Wheelbase  Width  \
# 0            31                None  ...          5    177        102     68
# 1            25  Driver & Passenger  ...          5    195        115     71
# 2            26         Driver only  ...          5    180        102     67
# 3            26  Driver & Passenger  ...          6    193        106     70
# 4            30         Driver only  ...          4    186        109     69
# ..          ...                 ...  ...        ...    ...        ...    ...
# 88           21                None  ...          7    187        115     72
# 89           30                None  ...          5    180        103     67
# 90           25                None  ...          4    159         97     66
# 91           28         Driver only  ...          5    190        104     67
# 92           28  Driver & Passenger  ...          5    184        105     69
#
#     Turn.circle  Rear.seat.room Luggage.room  Weight   Origin  \
# 0            37            26.5         11.0    2705  non-USA
# 1            38            30.0         15.0    3560  non-USA
# 2            37            28.0         14.0    3375  non-USA
# 3            37            31.0         17.0    3405  non-USA
# 4            39            27.0         13.0    3640  non-USA
# ..          ...             ...          ...     ...      ...
# 88           38            34.0          NaN    3960  non-USA
# 89           35            31.5         14.0    2985  non-USA
# 90           36            26.0         15.0    2810  non-USA
# 91           37            29.5         14.0    2985  non-USA
# 92           38            30.0         15.0    3245  non-USA
#
#                   Make
# 0        Acura Integra
# 1         Acura Legend
# 2              Audi 90
# 3             Audi 100
# 4             BMW 535i
# ..                 ...
# 88  Volkswagen Eurovan
# 89   Volkswagen Passat
# 90  Volkswagen Corrado
# 91           Volvo 240
# 92           Volvo 850
#
# [93 rows x 28 columns]

# %%
columns = ["Manufacturer","Model","Type","Price",
"MPG.city","MPG.highway","Horsepower","Rear.seat.room","Passengers"]
cars_df[columns]
# Out:
#    Manufacturer    Model     Type  Price  MPG.city  MPG.highway  Horsepower  \
# 0         Acura  Integra    Small   15.9        25           31         140
# 1         Acura   Legend  Midsize   33.9        18           25         200
# 2          Audi       90  Compact   29.1        20           26         172
# 3          Audi      100  Midsize   37.7        19           26         172
# 4           BMW     535i  Midsize   30.0        22           30         208
# ..          ...      ...      ...    ...       ...          ...         ...
# 88   Volkswagen  Eurovan      Van   19.7        17           21         109
# 89   Volkswagen   Passat  Compact   20.0        21           30         134
# 90   Volkswagen  Corrado   Sporty   23.3        18           25         178
# 91        Volvo      240  Compact   22.7        21           28         114
# 92        Volvo      850  Midsize   26.7        20           28         168
#
#     Rear.seat.room  Passengers
# 0             26.5           5
# 1             30.0           5
# 2             28.0           5
# 3             31.0           6
# 4             27.0           4
# ..             ...         ...
# 88            34.0           7
# 89            31.5           5
# 90            26.0           4
# 91            29.5           5
# 92            30.0           5
#
# [93 rows x 9 columns]

# %%
#setting the plot, width and height
fig, ax = plt.subplots(2, 3, sharey=True, sharex=True)
fig.set_figwidth(10)
fig.set_figheight(7)
#super-title
fig.suptitle("Multiple Box Plots", fontsize=16)
#accessing and creating the respective sub-plots
ax[0][0].boxplot(cars_df["Price"][cars_df["Type"]=="Compact"])
ax[0][0].set_title('Compact')
ax[0][1].boxplot(cars_df["Price"][cars_df["Type"]=="Large"])
ax[0][1].set_title('Large')
ax[0][2].boxplot(cars_df["Price"][cars_df["Type"]=="Midsize"])
ax[0][2].set_title('Midsize')
ax[1][0].boxplot(cars_df["Price"][cars_df["Type"]=="Small"])
ax[1][0].set_title('Small')
ax[1][1].boxplot(cars_df["Price"][cars_df["Type"]=="Sporty"])
ax[1][1].set_title('Sporty')
ax[1][2].boxplot(cars_df["Price"][cars_df["Type"]=="Van"])
ax[1][2].set_title('Van')
# Out:
# Text(0.5, 1.0, 'Van')

# %%
#To Plot the data as a scatter plot
ax = cars_df.plot(["Horsepower"],["MPG.city"],kind="scatter", color = "black",marker = "*",figsize=(10,7))
#To add labels and title to the output
ax.set_xlabel("Horsepower")	#sets label for x-axis
ax.set_ylabel("MPG.city")	#sets label for y-axis
ax.set_title("Horsepower vs MPG.city",fontsize=16)	#sets title for the graph
# Out:
# Text(0.5, 1.0, 'Horsepower vs MPG.city')

# %%
#First sort the data to get a proper line chart
cars_df=cars_df.sort_values(by="Horsepower")
#The following lines of code create a blank canvas to plot on
fig, ax = plt.subplots()
fig.set_figwidth(10)
fig.set_figheight(7)
#Data is fed and plotted using the following lines
cars_df.plot(ax = ax, x = "Horsepower", y = "MPG.highway", kind = "line", )
cars_df.plot(ax = ax, x = "Horsepower",y= "MPG.city", kind = "line", linestyle='--')
# Out:
# <AxesSubplot:xlabel='Horsepower'>

# %%
#horizontal bar graph
plt.barh(cars_df["DriveTrain"], cars_df["MPG.city"],height=0.2,label="Mileage in city")
plt.xlabel("MPG.city")
plt.ylabel("DriveTrain")
# Out:
# Text(0, 0.5, 'DriveTrain')

# %%
cars_df["Cylinders"].unique()
# Out:
# array(['3', '4', '5', '6', '8', 'rotary'], dtype=object)

# %%
grouped_data = cars_df[["Cylinders", "Type"]].groupby(by = ["Cylinders", "Type"]).size().unstack()
fig, ax = plt.subplots(2,3, figsize = (15,10))
grouped_data.plot.pie(ax = ax, subplots = True, fontsize = 20)
fig.suptitle("Number of cars for each type of cylinders", fontsize=26, x = 1, y = 2.1)
fig.tight_layout(rect=[0,0,2,2])

# %%
cars_df["MPG.city"].plot(kind="density")
cars_df["MPG.city"].plot(kind="hist",bins=15,density=True,figsize=(10,7))
plt.suptitle("Distribution of MPG.city",fontsize=16)
plt.xlim(14,50)
# Out:
# (14.0, 50.0)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
df1=pd.read_csv('C:/Users/Admin/Desktop/volcano_data_2010.csv')
df1.head()
# Out:
#      Year  Month   Day  TSU   EQ              Name              Location  \
# 0     NaN    NaN   NaN  NaN  NaN               NaN                   NaN
# 1  2010.0    1.0   NaN  NaN  NaN        Tungurahua               Ecuador
# 2  2010.0    3.0  31.0  NaN  NaN  Eyjafjallajokull             Iceland-S
# 3  2010.0    5.0  27.0  NaN  NaN            Pacaya             Guatemala
# 4  2010.0    5.0  29.0  TSU   EQ           Sarigan  Mariana Is-C Pacific
#
#          Country  Latitude  Longitude  ...  TOTAL_DEATHS  \
# 0            NaN       NaN        NaN  ...           NaN
# 1        Ecuador    -1.467    -78.442  ...           NaN
# 2        Iceland    63.630    -19.620  ...           2.0
# 3      Guatemala    14.381    -90.601  ...           1.0
# 4  United States    16.708    145.780  ...           NaN
#
#   TOTAL_DEATHS_DESCRIPTION TOTAL_MISSING TOTAL_MISSING_DESCRIPTION  \
# 0                      NaN           NaN                       NaN
# 1                      NaN           NaN                       NaN
# 2                      1.0           NaN                       NaN
# 3                      1.0           3.0                       1.0
# 4                      NaN           NaN                       NaN
#
#    TOTAL_INJURIES TOTAL_INJURIES_DESCRIPTION  TOTAL_DAMAGE_MILLIONS_DOLLARS  \
# 0             NaN                        NaN                            NaN
# 1             NaN                        NaN                            NaN
# 2             NaN                        NaN                            NaN
# 3             NaN                        NaN                            NaN
# 4             NaN                        NaN                            NaN
#
#    TOTAL_DAMAGE_DESCRIPTION  TOTAL_HOUSES_DESTROYED  \
# 0                       NaN                     NaN
# 1                       1.0                     NaN
# 2                       NaN                     NaN
# 3                       1.0                     3.0
# 4                       NaN                     NaN
#
#    TOTAL_HOUSES_DESTROYED_DESCRIPTION
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 1.0
# 4                                 NaN
#
# [5 rows x 36 columns]

# %%
df1.plot(x = 'Latitude',y = 'TOTAL_DEATHS' ,marker='o',kind = 'scatter');

# %%
df1['Latitude'].head().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
df1['TOTAL_DEATHS'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1['Longitude'].plot(kind = 'line chart')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [65], in <cell line: 1>()
# ----> 1 df1['Longitude'].plot(kind = 'line chart')
#
# File ~\anaconda3\lib\site-packages\pandas\plotting\_core.py:905, in PlotAccessor.__call__(self, *args, **kwargs)
#     902     return plot_backend.plot(self._parent, x=x, y=y, kind=kind, **kwargs)
#     904 if kind not in self._all_kinds:
# --> 905     raise ValueError(f"{kind} is not a valid plot kind")
#     907 # The original data structured can be transformed before passed to the
#     908 # backend. For example, for DataFrame is common to set the index as the
#     909 # `x` parameter, and return a Series with the parameter `y` as values.
#     910 data = self._parent.copy()
#
# ValueError: line chart is not a valid plot kind

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 36 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Year                                0 non-null      float64
#  1   Month                               0 non-null      float64
#  2   Day                                 0 non-null      float64
#  3   TSU                                 0 non-null      object
#  4   EQ                                  0 non-null      object
#  5   Name                                0 non-null      object
#  6   Location                            0 non-null      object
#  7   Country                             0 non-null      object
#  8   Latitude                            0 non-null      float64
#  9   Longitude                           0 non-null      float64
#  10  Elevation                           0 non-null      float64
#  11  Type                                0 non-null      object
#  12  Status                              0 non-null      object
#  13  Time                                0 non-null      object
#  14  VEI                                 0 non-null      float64
#  15  Agent                               0 non-null      object
#  16  DEATHS                              0 non-null      float64
#  17  DEATHS_DESCRIPTION                  0 non-null      float64
#  18  MISSING                             0 non-null      float64
#  19  MISSING_DESCRIPTION                 0 non-null      float64
#  20  INJURIES                            0 non-null      float64
#  21  INJURIES_DESCRIPTION                0 non-null      float64
#  22  DAMAGE_MILLIONS_DOLLARS             0 non-null      float64
#  23  DAMAGE_DESCRIPTION                  0 non-null      float64
#  24  HOUSES_DESTROYED                    0 non-null      float64
#  25  HOUSES_DESTROYED_DESCRIPTION        0 non-null      float64
#  26  TOTAL_DEATHS                        0 non-null      float64
#  27  TOTAL_DEATHS_DESCRIPTION            0 non-null      float64
#  28  TOTAL_MISSING                       0 non-null      float64
#  29  TOTAL_MISSING_DESCRIPTION           0 non-null      float64
#  30  TOTAL_INJURIES                      0 non-null      float64
#  31  TOTAL_INJURIES_DESCRIPTION          0 non-null      float64
#  32  TOTAL_DAMAGE_MILLIONS_DOLLARS       0 non-null      float64
#  33  TOTAL_DAMAGE_DESCRIPTION            0 non-null      float64
#  34  TOTAL_HOUSES_DESTROYED              0 non-null      float64
#  35  TOTAL_HOUSES_DESTROYED_DESCRIPTION  0 non-null      float64
# dtypes: float64(27), object(9)
# memory usage: 0.0+ bytes
