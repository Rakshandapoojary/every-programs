# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('C:/Users/Admin/Desktop/Cars93.csv')
df
# Out:
#     Id Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0    1        Acura  Integra    Small       12.9   15.9       18.8        25
# 1    2        Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2    3         Audi       90  Compact       25.9   29.1       32.3        20
# 3    4         Audi      100  Midsize       30.8   37.7       44.6        19
# 4    5          BMW     535i  Midsize       23.7   30.0       36.2        22
# ..  ..          ...      ...      ...        ...    ...        ...       ...
# 88  89   Volkswagen  Eurovan      Van       16.6   19.7       22.7        17
# 89  90   Volkswagen   Passat  Compact       17.6   20.0       22.4        21
# 90  91   Volkswagen  Corrado   Sporty       22.9   23.3       23.7        18
# 91  92        Volvo      240  Compact       21.8   22.7       23.5        21
# 92  93        Volvo      850  Midsize       24.8   26.7       28.5        20
#
# ...

# %%
fig=plt.figure(figsize=[4,4])
ax=fig.add_axes([0,0,1,1])
ax.set_title('distribution',fontsize=15)
ax.set_xlabel('values',fontsize=15)
ax.set_ylabel('needs',fontsize=15)
ax.scatter(df['Length'],df['Width'],color='C3')
fig.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8348\121982130.py:7: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig=plt.figure(figsize=[4,4])
ax=fig.add_axes([0,0,1,1])
ax.set_title('distribution',fontsize=10)
ax.set_xlabel('values',fontsize=15)
ax.set_ylabel('needs',fontsize=15)
ax.hist(df['Length'],color='C4',bins=3)
fig.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8348\522374973.py:7: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig=plt.figure(figsize=[4,4])
ax=fig.add_axes([0,0,1,1])
ax.set_title('distribution',fontsize=15)
ax.set_xlabel('values',fontsize=15)
ax.set_ylabel('needs',fontsize=15)
ax.plot(df['Width'],color='C4')
fig.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8348\3543080520.py:7: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig=plt.figure(figsize=[4,4])
ax=fig.add_axes([0,0,1,1])
ax.set_title('distribution',fontsize=15)
ax.set_xlabel('values',fontsize=15)
ax.set_ylabel('needs',fontsize=15)
ax.boxplot(df['Weight'])
fig.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8348\908193147.py:7: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
import numpy as np
x=lambda n:n**2
x(4)
# Out:
# 16

# %%
import numpy as np
x=lambda x:x[1]=='a'
x('banana')
# Out:
# True

# %%
import numpy as np
x= lambda x,y:x+y
x(2,3)
# Out:
# 5

# %%
import numpy as np
l=[1,2,3,4,5]
l
list(map(lambda x:x*2,l))
# Out:
# [2, 4, 6, 8, 10]

# %%
import numpy as np
l=[1,2,3,4,5,6,7]
l
list(map(lambda x:x%2==0,l))
# Out:
# [False, True, False, True, False, True, False]

# %%
import numpy as np
l=[1,2,3,4,5,6,7,8]
list(filter(lambda x:x>6,l))
# Out:
# [7, 8]

# %%
import numpy as np
import functools
l1=[2,3,4,5]
functools.reduce(lambda x,y:x if x>y else y,l1)
# Out:
# 5

# %%
import pandas as pd
data=pd.read_csv('C:/Users/Admin/Desktop/rainfall.csv')
data
# Out:
#                    STATE_UT_NAME        DISTRICT    JAN   FEB    MAR    APR  \
# 0    ANDAMAN And NICOBAR ISLANDS         NICOBAR  107.3  57.9   65.2  117.0
# 1    ANDAMAN And NICOBAR ISLANDS   SOUTH ANDAMAN   43.7  26.0   18.6   90.5
# 2    ANDAMAN And NICOBAR ISLANDS   N & M ANDAMAN   32.7  15.9    8.6   53.4
# 3              ARUNACHAL PRADESH           LOHIT   42.2  80.8  176.4  358.5
# 4              ARUNACHAL PRADESH      EAST SIANG   33.3  79.5  105.9  216.5
# ..                           ...             ...    ...   ...    ...    ...
# 636                       KERALA          IDUKKI   13.4  22.1   43.6  150.4
# 637                       KERALA        KASARGOD    2.3   1.0    8.4   46.9
# 638                       KERALA  PATHANAMTHITTA   19.8  45.2   73.9  184.9
# 639                       KERALA         WAYANAD    4.8   8.3   17.5   83.3
# 640                  LAKSHADWEEP     LAKSHADWEEP   20.8  14.7   11.8   48.9
#
# ...

# %%
data.groupby('JAN')

# %%
data.groupby(by=['JAN']).mean()
# Out:
#               FEB         MAR         APR         MAY         JUN  \
# JAN
# 0.0      0.050000    0.850000    0.100000    6.750000  229.100000
# 0.1      0.000000    0.100000    3.500000   31.700000  829.900000
# 0.2      0.166667    0.166667    0.933333   12.966667  397.633333
# 0.3      0.160000    1.760000   14.100000   51.840000  399.420000
# 0.4      0.200000    0.233333    3.000000   36.366667  573.333333
# ...           ...         ...         ...         ...         ...
# 119.4  161.800000  213.500000  127.500000  100.400000   72.600000
# 126.2  112.800000  120.300000   51.200000   53.400000  132.400000
# 132.8  137.100000  176.600000  108.900000   91.700000   52.400000
# 138.9  124.200000  158.500000   99.000000   69.600000  116.600000
# 144.5  190.800000  211.600000  112.900000   85.000000   61.400000
#
#                JUL         AUG         SEP         OCT        NOV        DEC  \
# JAN
# 0.0     535.100000  384.650000  220.400000   29.850000  11.250000   2.250000
# ...

# %%
a=data.groupby(by=['JAN','FEB']).sum()
a
# Out:
#                MAR    APR    MAY    JUN     JUL    AUG    SEP    OCT   NOV  \
# JAN   FEB
# 0.0   0.0      0.8    0.1    8.1  234.8   574.5  442.7  232.9   28.0  11.0
#       0.1      0.9    0.1    5.4  223.4   495.7  326.6  207.9   31.7  11.5
# 0.1   0.0      0.1    3.5   31.7  829.9  1212.7  859.2  359.7  143.1  24.9
# 0.2   0.0      0.1    0.3    4.7   99.7   168.8  148.1   83.2   17.5  11.3
#       0.2      0.1    1.8   20.3  656.8  1209.8  852.8  398.3  114.6  19.7
# ...            ...    ...    ...    ...     ...    ...    ...    ...   ...
# 119.4 161.8  427.0  255.0  200.8  145.2   292.8  251.6  193.2   81.8  93.0
# 126.2 112.8  120.3   51.2   53.4  132.4   567.3  479.2  227.5   48.7  21.9
# 132.8 137.1  176.6  108.9   91.7   52.4   164.5  139.9  101.4   52.2  29.6
# 138.9 124.2  158.5   99.0   69.6  116.6   344.2  191.5  108.2   27.4  40.4
# 144.5 190.8  211.6  112.9   85.0   61.4   132.2  120.2   86.8   42.1  43.6
#
# ...

# %%
agg_function={'MAR':['sum','mean','median','min','max']}
agg_function
# Out:
# {'MAR': ['sum', 'mean', 'median', 'min', 'max']}

# %%
data.groupby(['FEB']).aggfunc=['agg_functions']
data
# Out:
#                    STATE_UT_NAME        DISTRICT    JAN   FEB    MAR    APR  \
# 0    ANDAMAN And NICOBAR ISLANDS         NICOBAR  107.3  57.9   65.2  117.0
# 1    ANDAMAN And NICOBAR ISLANDS   SOUTH ANDAMAN   43.7  26.0   18.6   90.5
# 2    ANDAMAN And NICOBAR ISLANDS   N & M ANDAMAN   32.7  15.9    8.6   53.4
# 3              ARUNACHAL PRADESH           LOHIT   42.2  80.8  176.4  358.5
# 4              ARUNACHAL PRADESH      EAST SIANG   33.3  79.5  105.9  216.5
# ..                           ...             ...    ...   ...    ...    ...
# 636                       KERALA          IDUKKI   13.4  22.1   43.6  150.4
# 637                       KERALA        KASARGOD    2.3   1.0    8.4   46.9
# 638                       KERALA  PATHANAMTHITTA   19.8  45.2   73.9  184.9
# 639                       KERALA         WAYANAD    4.8   8.3   17.5   83.3
# 640                  LAKSHADWEEP     LAKSHADWEEP   20.8  14.7   11.8   48.9
#
# ...

# %%
df=pd.DataFrame([[9,4,8,9],
                [8,10,7,6],
                [7,6,8,5]],
columns=['maths','english','science','history'])
print(df)
# Out:
#    maths  english  science  history
# 0      9        4        8        9
# 1      8       10        7        6
# 2      7        6        8        5

# %%
df.sum()
# Out:
# maths      24
# english    20
# science    23
# history    20
# dtype: int64

# %%
df.mean()
# Out:
# maths      8.000000
# english    6.666667
# science    7.666667
# history    6.666667
# dtype: float64

# %%
df.min()
# Out:
# maths      7
# english    4
# science    7
# history    5
# dtype: int64

# %%
df.describe()
# Out:
#        maths    english   science   history
# count    3.0   3.000000  3.000000  3.000000
# mean     8.0   6.666667  7.666667  6.666667
# std      1.0   3.055050  0.577350  2.081666
# min      7.0   4.000000  7.000000  5.000000
# 25%      7.5   5.000000  7.500000  5.500000
# 50%      8.0   6.000000  8.000000  6.000000
# 75%      8.5   8.000000  8.000000  7.500000
# max      9.0  10.000000  8.000000  9.000000

# %%
df.agg(['sum','min','max','std','count'])
# Out:
#        maths   english   science    history
# sum     24.0  20.00000  23.00000  20.000000
# min      7.0   4.00000   7.00000   5.000000
# max      9.0  10.00000   8.00000   9.000000
# std      1.0   3.05505   0.57735   2.081666
# count    3.0   3.00000   3.00000   3.000000

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('C:/Users/Admin/Desktop/rainfall.csv')
df
# Out:
#                    STATE_UT_NAME        DISTRICT    JAN   FEB    MAR    APR  \
# 0    ANDAMAN And NICOBAR ISLANDS         NICOBAR  107.3  57.9   65.2  117.0
# 1    ANDAMAN And NICOBAR ISLANDS   SOUTH ANDAMAN   43.7  26.0   18.6   90.5
# 2    ANDAMAN And NICOBAR ISLANDS   N & M ANDAMAN   32.7  15.9    8.6   53.4
# 3              ARUNACHAL PRADESH           LOHIT   42.2  80.8  176.4  358.5
# 4              ARUNACHAL PRADESH      EAST SIANG   33.3  79.5  105.9  216.5
# ..                           ...             ...    ...   ...    ...    ...
# 636                       KERALA          IDUKKI   13.4  22.1   43.6  150.4
# 637                       KERALA        KASARGOD    2.3   1.0    8.4   46.9
# 638                       KERALA  PATHANAMTHITTA   19.8  45.2   73.9  184.9
# 639                       KERALA         WAYANAD    4.8   8.3   17.5   83.3
# 640                  LAKSHADWEEP     LAKSHADWEEP   20.8  14.7   11.8   48.9
#
# ...

# %%
fig=plt.figure(figsize=[4,4])
ax=fig.add_axes([0,0,1,1])
ax.set_title('frequency',fontsize=15)
ax.set_xlabel('value',fontsize=15)
ax.set_ylabel('needs',fontsize=15)
ax.scatter(df['JAN'],df['FEB'])
fig.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8348\3812830064.py:7: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig=plt.figure(figsize=[4,4])
ax=fig.add_axes([0,0,1,1])
ax.set_title('frequency',fontsize=15)
ax.set_xlabel('value',fontsize=15)
ax.set_ylabel('needs',fontsize=15)
ax.hist(df['MAY'])
fig.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8348\3544863486.py:7: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig=plt.figure(figsize=[4,4])
ax=fig.add_axes([0,0,1,1])
ax.set_title('frequency',fontsize=15)
ax.set_xlabel('value',fontsize=15)
ax.set_ylabel('needs',fontsize=15)
ax.plot(df['MAY'])
fig.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8348\22812653.py:7: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig=plt.figure(figsize=[4,4])
ax=fig.add_axes([0,0,1,1])
ax.set_title('frequency',fontsize=15)
ax.set_xlabel('value',fontsize=15)
ax.set_ylabel('needs',fontsize=15)
ax.boxplot(df['SEP'])
fig.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8348\3162480569.py:7: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig=plt.figure(figsize=[4,4])
ax=fig.add_axes([0,0,1,1])
ax.set_title('frequency',fontsize=15)
ax.set_xlabel('value',fontsize=15)
ax.set_ylabel('needs',fontsize=15)
ax.plot(df['MAY']/10,label='MAY'/10)
ax.plot(df['FEB']/1000,label='FEB'/1000)
ax.plot(df['SEP']/100,label='SEP'/100)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [103], in <cell line: 6>()
#       4 ax.set_xlabel('value',fontsize=15)
#       5 ax.set_ylabel('needs',fontsize=15)
# ----> 6 ax.plot(df['MAY']/10,label='MAY'/10)
#       7 ax.plot(df['FEB']/1000,label='FEB'/1000)
#       8 ax.plot(df['SEP']/100,label='SEP'/100)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv('C:/Users/Admin/Downloads/a412dfbd88b3db70b74b-5f23f993cd87c283ce766e7ac6b329ee7cc2e1d1/mtcars.csv') 
data
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
fig=plt.figure(figsize=[4,4])
ax=fig.add_axes([0,0,1,1])
ax.set_title('distribution',fontsize=16)
ax.set_xlabel('frequency',fontsize=16)
ax.set_ylabel('values',fontsize=16)
ax.scatter(data['mpg'],data['wt'])
fig.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_2024\2923084516.py:7: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig=plt.figure(figsize=[4,4])
ax=fig.add_axes([0,0,1,1])
ax.set_title('distribution',fontsize=16)
ax.set_xlabel('frequency',fontsize=16)
ax.set_ylabel('values',fontsize=16)
ax.hist(data['mpg'])
fig.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_2024\2489222235.py:7: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig=plt.figure(figsize=[4,4])
ax=fig.add_axes([0,0,1,1])
ax.set_title('distribution',fontsize=16)
ax.set_xlabel('frequency',fontsize=16)
ax.set_ylabel('values',fontsize=16)
ax.plot(data['mpg'])
fig.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_2024\3798704902.py:7: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig=plt.figure(figsize=[4,4])
ax=fig.add_axes([0,0,1,1])
ax.set_title('distribution',fontsize=16)
ax.set_xlabel('frequency',fontsize=16)
ax.set_ylabel('values',fontsize=16)
ax.boxplot(data['mpg'])
fig.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_2024\4063000580.py:7: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
import pandas as pd
data={'school':['s001','s002','s003','s001','s002','s004'],
     'class':['V','V','VI','VI','V','VI'],
     'name':['Alberto Franco','Gino Mcneill','Ryan Parkes','Eesha Hinton','Gino Mcneill','David Parkes'],
     'date_of_birth':['15/5/2002','17/5/2002','16/2/1999','25/9/1998','11/5/2002','15/9/1997'],
      'age':[12,12,13,13,14,12],
      'height':[173,192,186,167,151,159],
      'weight':[35,32,33,30,31,32],
      'address':['street1','street2','street3','street1','street2','street4']}
df=pd.DataFrame(data,index=['s1','s2','s3','s4','s5','s6'])
df
# Out:
#    school class            name date_of_birth  age  height  weight  address
# s1   s001     V  Alberto Franco     15/5/2002   12     173      35  street1
# s2   s002     V    Gino Mcneill     17/5/2002   12     192      32  street2
# s3   s003    VI     Ryan Parkes     16/2/1999   13     186      33  street3
# s4   s001    VI    Eesha Hinton     25/9/1998   13     167      30  street1
# s5   s002     V    Gino Mcneill     11/5/2002   14     151      31  street2
# s6   s004    VI    David Parkes     15/9/1997   12     159      32  street4

# %%
a=df.groupby(['school'])
a.tail()
# Out:
#    school class            name date_of_birth  age  height  weight  address
# s1   s001     V  Alberto Franco     15/5/2002   12     173      35  street1
# s2   s002     V    Gino Mcneill     17/5/2002   12     192      32  street2
# s3   s003    VI     Ryan Parkes     16/2/1999   13     186      33  street3
# s4   s001    VI    Eesha Hinton     25/9/1998   13     167      30  street1
# s5   s002     V    Gino Mcneill     11/5/2002   14     151      31  street2
# s6   s004    VI    David Parkes     15/9/1997   12     159      32  street4

# %%
a=df.groupby(['school'])
a.first()
# Out:
#        class            name date_of_birth  age  height  weight  address
# school
# s001       V  Alberto Franco     15/5/2002   12     173      35  street1
# s002       V    Gino Mcneill     17/5/2002   12     192      32  street2
# s003      VI     Ryan Parkes     16/2/1999   13     186      33  street3
# s004      VI    David Parkes     15/9/1997   12     159      32  street4

# %%
import pandas as pd
pd.set_option('display.max_rows', None)
#pd.set_option('display.max_columns', None)
student_data = pd.DataFrame({
    'school_code': ['s001','s002','s003','s001','s002','s004'],
    'class': ['V', 'V', 'VI', 'VI', 'V', 'VI'],
    'name': ['Alberto Franco','Gino Mcneill','Ryan Parkes', 'Eesha Hinton', 'Gino Mcneill', 'David Parkes'],
    'date_Of_Birth ': ['15/05/2002','17/05/2002','16/02/1999','25/09/1998','11/05/2002','15/09/1997'],
    'age': [12, 12, 13, 13, 14, 12],
    'height': [173, 192, 186, 167, 151, 159],
    'weight': [35, 32, 33, 30, 31, 32],
    'address': ['street1', 'street2', 'street3', 'street1', 'street2', 'street4']},
    index=['S1', 'S2', 'S3', 'S4', 'S5', 'S6'])

print("Original DataFrame:")
print(student_data)
print('\nSplit the said data on school_code wise:')
result = student_data.groupby(['school_code'])
for name,group in result:
    print("\nGroup:")
    print(name)
    print(group)
print("\nType of the object:")
print(type(result))
# Out:
# Original DataFrame:
#    school_code class            name date_Of_Birth   age  height  weight  \
# S1        s001     V  Alberto Franco     15/05/2002   12     173      35
# S2        s002     V    Gino Mcneill     17/05/2002   12     192      32
# S3        s003    VI     Ryan Parkes     16/02/1999   13     186      33
# S4        s001    VI    Eesha Hinton     25/09/1998   13     167      30
# S5        s002     V    Gino Mcneill     11/05/2002   14     151      31
# S6        s004    VI    David Parkes     15/09/1997   12     159      32
#
#     address
# S1  street1
# S2  street2
# S3  street3
# S4  street1
# S5  street2
# S6  street4
#
# Split the said data on school_code wise:
#
# Group:
# s001
#    school_code class            name date_Of_Birth   age  height  weight  \
# S1        s001     V  Alberto Franco     15/05/2002   12     173      35
# S4        s001    VI    Eesha Hinton     25/09/1998   13     167      30
#
#     address
# S1  street1
# S4  street1
#
# Group:
# ...

# %%
import pandas as pd
data=({'school':['s001','s002','s003','s001','s002','s004'],
     'class':['V','V','VI','VI','V','VI'],
     'name':['Alberto Franco','Gino Mcneill','Ryan Parkes','Eesha Hinton','Gino Mcneill','David Parkes'],
     'date_of_birth':[15/5/2002,17/5/2002,16/2/1999,25/9/1998,11/5/2002,15/9/1997],
      'age':[12,12,13,13,14,12],
      'height':[173,192,186,167,151,159],
      'weight':[35,32,33,30,31,32],
      'address':['street1','street2','street3','street1','street2','street4']})
df=pd.DataFrame(data,index=['s1','s2','s3','s4','s5','s6'])
df
# Out:
#    school class            name  date_of_birth  age  height  weight  address
# s1   s001     V  Alberto Franco       0.001499   12     173      35  street1
# s2   s002     V    Gino Mcneill       0.001698   12     192      32  street2
# s3   s003    VI     Ryan Parkes       0.004002   13     186      33  street3
# s4   s001    VI    Eesha Hinton       0.001390   13     167      30  street1
# s5   s002     V    Gino Mcneill       0.001099   14     151      31  street2
# s6   s004    VI    David Parkes       0.000835   12     159      32  street4

# %%
agg_functions={'age':['mean','min','max']}
df.groupby(['school']).agg(agg_functions)
# Out:
#          age
#         mean min max
# school
# s001    12.5  12  13
# s002    13.0  12  14
# s003    13.0  13  13
# s004    12.0  12  12

# %%
a=df.groupby(['school','class'])
a.first()
# Out:
#                         name  date_of_birth  age  height  weight  address
# school class
# s001   V      Alberto Franco       0.001499   12     173      35  street1
#        VI       Eesha Hinton       0.001390   13     167      30  street1
# s002   V        Gino Mcneill       0.001698   12     192      32  street2
# s003   VI        Ryan Parkes       0.004002   13     186      33  street3
# s004   VI       David Parkes       0.000835   12     159      32  street4

# %%
a=df.groupby(['school']).apply(list)
a
# Out:
# school
# s001    [school, class, name, date_of_birth, age, heig...
# s002    [school, class, name, date_of_birth, age, heig...
# s003    [school, class, name, date_of_birth, age, heig...
# s004    [school, class, name, date_of_birth, age, heig...
# dtype: object

# %%
a=df.groupby([''])
