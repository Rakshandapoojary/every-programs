# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('C:/Users/Admin/Desktop/Cars93.csv')
df
# Out:
#     Id Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0    1        Acura  Integra    Small       12.9   15.9       18.8        25
# 1    2        Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2    3         Audi       90  Compact       25.9   29.1       32.3        20
# 3    4         Audi      100  Midsize       30.8   37.7       44.6        19
# 4    5          BMW     535i  Midsize       23.7   30.0       36.2        22
# ..  ..          ...      ...      ...        ...    ...        ...       ...
# 88  89   Volkswagen  Eurovan      Van       16.6   19.7       22.7        17
# 89  90   Volkswagen   Passat  Compact       17.6   20.0       22.4        21
# 90  91   Volkswagen  Corrado   Sporty       22.9   23.3       23.7        18
# 91  92        Volvo      240  Compact       21.8   22.7       23.5        21
# 92  93        Volvo      850  Midsize       24.8   26.7       28.5        20
#
#     MPG.highway             AirBags  ... Passengers Length  Wheelbase  Width  \
# 0            31                None  ...          5    177        102     68
# 1            25  Driver & Passenger  ...          5    195        115     71
# 2            26         Driver only  ...          5    180        102     67
# 3            26  Driver & Passenger  ...          6    193        106     70
# 4            30         Driver only  ...          4    186        109     69
# ..          ...                 ...  ...        ...    ...        ...    ...
# 88           21                None  ...          7    187        115     72
# 89           30                None  ...          5    180        103     67
# 90           25                None  ...          4    159         97     66
# 91           28         Driver only  ...          5    190        104     67
# 92           28  Driver & Passenger  ...          5    184        105     69
#
#     Turn.circle  Rear.seat.room Luggage.room  Weight   Origin  \
# 0            37            26.5         11.0    2705  non-USA
# 1            38            30.0         15.0    3560  non-USA
# 2            37            28.0         14.0    3375  non-USA
# 3            37            31.0         17.0    3405  non-USA
# 4            39            27.0         13.0    3640  non-USA
# ..          ...             ...          ...     ...      ...
# 88           38            34.0          NaN    3960  non-USA
# 89           35            31.5         14.0    2985  non-USA
# 90           36            26.0         15.0    2810  non-USA
# 91           37            29.5         14.0    2985  non-USA
# 92           38            30.0         15.0    3245  non-USA
#
#                   Make
# 0        Acura Integra
# 1         Acura Legend
# 2              Audi 90
# 3             Audi 100
# 4             BMW 535i
# ..                 ...
# 88  Volkswagen Eurovan
# 89   Volkswagen Passat
# 90  Volkswagen Corrado
# 91           Volvo 240
# 92           Volvo 850
#
# [93 rows x 28 columns]

# %%
fig=plt.figure(figsize=[4,4])
ax=fig.add_axes([0,0,1,1])
ax.set_title('',fontsize=15)
ax.set_xlabel('values',fontsize=15)
ax.set_ylabel('needs',fontsize=15)
ax.scatter(df['Horsepower'],df['MPG.city'],color='C3')
fig.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8996\3990975067.py:7: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig=plt.figure(figsize=[4,4])
ax=fig.add_axes([0,0,1,1])
ax.set_title('distribution',fontsize=10)
ax.set_xlabel('values',fontsize=15)
ax.set_ylabel('needs',fontsize=15)
ax.hist(df['MPG.city'],color='C4',bins=3)
fig.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8996\3430931308.py:7: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig=plt.figure(figsize=[4,4])
ax=fig.add_axes([0,0,1,1])
ax.set_title('distribution',fontsize=15)
ax.set_xlabel('values',fontsize=15)
ax.set_ylabel('needs',fontsize=15)
ax.boxplot(df['Price'])
fig.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8996\3145282492.py:7: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
line_df=df.groupby(by=['Horsepower'])
line_df=line_df.mean()
import matplotlib.pyplot as plt
fig=plt.figure(figsize=[3,3])
ax=fig.add_axes([0,0,1,1])
plt.plot(df['Horsepower'],df['EngineSize'],label='EngineSize')
ax.set_title('variation in enginesize')
ax.set_xlabel("Horsepower")
ax.legend()
fig.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8996\2168844634.py:10: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
