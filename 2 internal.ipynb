# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('C:/Users/Admin/Desktop/rainfall_duplicate.csv')
data
# Out:
#                    STATE_UT_NAME        DISTRICT    JAN   FEB    MAR    APR  \
# 0    ANDAMAN And NICOBAR ISLANDS         NICOBAR  107.3  57.9   65.2  117.0
# 1    ANDAMAN And NICOBAR ISLANDS   SOUTH ANDAMAN    NaN  26.0   18.6   90.5
# 2    ANDAMAN And NICOBAR ISLANDS   N & M ANDAMAN   32.7  15.9    8.6   53.4
# 3              ARUNACHAL PRADESH           LOHIT   42.2  80.8  176.4  358.5
# 4              ARUNACHAL PRADESH      EAST SIANG   33.3  79.5  105.9  216.5
# ..                           ...             ...    ...   ...    ...    ...
# 636                       KERALA          IDUKKI   13.4  22.1   43.6  150.4
# 637                       KERALA        KASARGOD    2.3   1.0    8.4   46.9
# 638                       KERALA  PATHANAMTHITTA   19.8  45.2   73.9  184.9
# 639                       KERALA         WAYANAD    4.8   8.3   17.5   83.3
# 640                  LAKSHADWEEP     LAKSHADWEEP   20.8  14.7   11.8   48.9
#
# ...

# %% [markdown]
# # MISSING VALUE

# %%
data.isnull()
# Out:
#      STATE_UT_NAME  DISTRICT    JAN    FEB    MAR    APR    MAY    JUN    JUL  \
# 0            False     False  False  False  False  False  False  False  False
# 1            False     False   True  False  False  False  False  False  False
# 2            False     False  False  False  False  False  False  False  False
# 3            False     False  False  False  False  False  False  False  False
# 4            False     False  False  False  False  False  False  False  False
# ..             ...       ...    ...    ...    ...    ...    ...    ...    ...
# 636          False     False  False  False  False  False  False  False  False
# 637          False     False  False  False  False  False  False  False  False
# 638          False     False  False  False  False  False  False  False  False
# 639          False     False  False  False  False  False  False  False  False
# 640          False     False  False  False  False  False  False  False  False
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 641 entries, 0 to 640
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   STATE_UT_NAME  641 non-null    object
#  1   DISTRICT       641 non-null    object
#  2   JAN            640 non-null    float64
#  3   FEB            640 non-null    float64
#  4   MAR            640 non-null    float64
#  5   APR            641 non-null    float64
#  6   MAY            641 non-null    float64
#  7   JUN            640 non-null    float64
#  8   JUL            641 non-null    float64
#  9   AUG            641 non-null    float64
#  10  SEP            641 non-null    float64
#  11  OCT            641 non-null    float64
#  12  NOV            641 non-null    float64
#  13  DEC            641 non-null    float64
#  14  ANNUAL         641 non-null    float64
#  15  Jan-Feb        641 non-null    float64
#  16  Mar-May        641 non-null    float64
# ...

# %% [markdown]
# # REPLACING WITH MEAN VALUE

# %%
data.fillna(0)
# Out:
#                    STATE_UT_NAME        DISTRICT    JAN   FEB    MAR    APR  \
# 0    ANDAMAN And NICOBAR ISLANDS         NICOBAR  107.3  57.9   65.2  117.0
# 1    ANDAMAN And NICOBAR ISLANDS   SOUTH ANDAMAN    0.0  26.0   18.6   90.5
# 2    ANDAMAN And NICOBAR ISLANDS   N & M ANDAMAN   32.7  15.9    8.6   53.4
# 3              ARUNACHAL PRADESH           LOHIT   42.2  80.8  176.4  358.5
# 4              ARUNACHAL PRADESH      EAST SIANG   33.3  79.5  105.9  216.5
# ..                           ...             ...    ...   ...    ...    ...
# 636                       KERALA          IDUKKI   13.4  22.1   43.6  150.4
# 637                       KERALA        KASARGOD    2.3   1.0    8.4   46.9
# 638                       KERALA  PATHANAMTHITTA   19.8  45.2   73.9  184.9
# 639                       KERALA         WAYANAD    4.8   8.3   17.5   83.3
# 640                  LAKSHADWEEP     LAKSHADWEEP   20.8  14.7   11.8   48.9
#
# ...

# %%
data['JAN'].fillna(data['JAN'].mean(),inplace=True)

# %%
data
# Out:
#                    STATE_UT_NAME        DISTRICT         JAN   FEB    MAR  \
# 0    ANDAMAN And NICOBAR ISLANDS         NICOBAR  107.300000  57.9   65.2
# 1    ANDAMAN And NICOBAR ISLANDS   SOUTH ANDAMAN   18.315469  26.0   18.6
# 2    ANDAMAN And NICOBAR ISLANDS   N & M ANDAMAN   32.700000  15.9    8.6
# 3              ARUNACHAL PRADESH           LOHIT   42.200000  80.8  176.4
# 4              ARUNACHAL PRADESH      EAST SIANG   33.300000  79.5  105.9
# ..                           ...             ...         ...   ...    ...
# 636                       KERALA          IDUKKI   13.400000  22.1   43.6
# 637                       KERALA        KASARGOD    2.300000   1.0    8.4
# 638                       KERALA  PATHANAMTHITTA   19.800000  45.2   73.9
# 639                       KERALA         WAYANAD    4.800000   8.3   17.5
# 640                  LAKSHADWEEP     LAKSHADWEEP   20.800000  14.7   11.8
#
#        APR    MAY    JUN     JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  \
# ...

# %% [markdown]
# # DROPNA

# %%
data.dropna()
# Out:
#                    STATE_UT_NAME        DISTRICT         JAN   FEB    MAR  \
# 0    ANDAMAN And NICOBAR ISLANDS         NICOBAR  107.300000  57.9   65.2
# 1    ANDAMAN And NICOBAR ISLANDS   SOUTH ANDAMAN   18.315469  26.0   18.6
# 2    ANDAMAN And NICOBAR ISLANDS   N & M ANDAMAN   32.700000  15.9    8.6
# 3              ARUNACHAL PRADESH           LOHIT   42.200000  80.8  176.4
# 4              ARUNACHAL PRADESH      EAST SIANG   33.300000  79.5  105.9
# ..                           ...             ...         ...   ...    ...
# 636                       KERALA          IDUKKI   13.400000  22.1   43.6
# 637                       KERALA        KASARGOD    2.300000   1.0    8.4
# 638                       KERALA  PATHANAMTHITTA   19.800000  45.2   73.9
# 639                       KERALA         WAYANAD    4.800000   8.3   17.5
# 640                  LAKSHADWEEP     LAKSHADWEEP   20.800000  14.7   11.8
#
#        APR    MAY    JUN     JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 641 entries, 0 to 640
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   STATE_UT_NAME  641 non-null    object
#  1   DISTRICT       641 non-null    object
#  2   JAN            641 non-null    float64
#  3   FEB            640 non-null    float64
#  4   MAR            640 non-null    float64
#  5   APR            641 non-null    float64
#  6   MAY            641 non-null    float64
#  7   JUN            640 non-null    float64
#  8   JUL            641 non-null    float64
#  9   AUG            641 non-null    float64
#  10  SEP            641 non-null    float64
#  11  OCT            641 non-null    float64
#  12  NOV            641 non-null    float64
#  13  DEC            641 non-null    float64
#  14  ANNUAL         641 non-null    float64
#  15  Jan-Feb        641 non-null    float64
#  16  Mar-May        641 non-null    float64
# ...

# %%
df= data.drop('JAN',axis=1)
df
# Out:
#                    STATE_UT_NAME        DISTRICT   FEB    MAR    APR    MAY  \
# 0    ANDAMAN And NICOBAR ISLANDS         NICOBAR  57.9   65.2  117.0  358.5
# 1    ANDAMAN And NICOBAR ISLANDS   SOUTH ANDAMAN  26.0   18.6   90.5  374.4
# 2    ANDAMAN And NICOBAR ISLANDS   N & M ANDAMAN  15.9    8.6   53.4  343.6
# 3              ARUNACHAL PRADESH           LOHIT  80.8  176.4  358.5  306.4
# 4              ARUNACHAL PRADESH      EAST SIANG  79.5  105.9  216.5  323.0
# ..                           ...             ...   ...    ...    ...    ...
# 636                       KERALA          IDUKKI  22.1   43.6  150.4  232.6
# 637                       KERALA        KASARGOD   1.0    8.4   46.9  217.6
# 638                       KERALA  PATHANAMTHITTA  45.2   73.9  184.9  294.7
# 639                       KERALA         WAYANAD   8.3   17.5   83.3  174.6
# 640                  LAKSHADWEEP     LAKSHADWEEP  14.7   11.8   48.9  171.7
#
# ...

# %%
data
# Out:
#                    STATE_UT_NAME        DISTRICT         JAN   FEB    MAR  \
# 0    ANDAMAN And NICOBAR ISLANDS         NICOBAR  107.300000  57.9   65.2
# 1    ANDAMAN And NICOBAR ISLANDS   SOUTH ANDAMAN   18.315469  26.0   18.6
# 2    ANDAMAN And NICOBAR ISLANDS   N & M ANDAMAN   32.700000  15.9    8.6
# 3              ARUNACHAL PRADESH           LOHIT   42.200000  80.8  176.4
# 4              ARUNACHAL PRADESH      EAST SIANG   33.300000  79.5  105.9
# ..                           ...             ...         ...   ...    ...
# 636                       KERALA          IDUKKI   13.400000  22.1   43.6
# 637                       KERALA        KASARGOD    2.300000   1.0    8.4
# 638                       KERALA  PATHANAMTHITTA   19.800000  45.2   73.9
# 639                       KERALA         WAYANAD    4.800000   8.3   17.5
# 640                  LAKSHADWEEP     LAKSHADWEEP   20.800000  14.7   11.8
#
#        APR    MAY    JUN     JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  \
# ...

# %%
data['JAN'].fillna(data['JAN'].mode(),inplace=True)

# %%
data
# Out:
#                    STATE_UT_NAME        DISTRICT         JAN   FEB    MAR  \
# 0    ANDAMAN And NICOBAR ISLANDS         NICOBAR  107.300000  57.9   65.2
# 1    ANDAMAN And NICOBAR ISLANDS   SOUTH ANDAMAN   18.315469  26.0   18.6
# 2    ANDAMAN And NICOBAR ISLANDS   N & M ANDAMAN   32.700000  15.9    8.6
# 3              ARUNACHAL PRADESH           LOHIT   42.200000  80.8  176.4
# 4              ARUNACHAL PRADESH      EAST SIANG   33.300000  79.5  105.9
# ..                           ...             ...         ...   ...    ...
# 636                       KERALA          IDUKKI   13.400000  22.1   43.6
# 637                       KERALA        KASARGOD    2.300000   1.0    8.4
# 638                       KERALA  PATHANAMTHITTA   19.800000  45.2   73.9
# 639                       KERALA         WAYANAD    4.800000   8.3   17.5
# 640                  LAKSHADWEEP     LAKSHADWEEP   20.800000  14.7   11.8
#
#        APR    MAY    JUN     JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  \
# ...

# %% [markdown]
# # NORMALIZATION

# %%
from sklearn.preprocessing import StandardScaler
# finding the mean and std deviation of numerical columns
scaler = StandardScaler().fit(data[['FEB', 'MAR']]) 
# scaling columns to a common range
data_normalized = scaler.transform(data[['FEB','MAR']])# Scaled data 
#note that output is a 2-Dimensional array of normalized data
data_normalized
# Out:
# array([[ 1.36349715,  0.80626583],
#        [ 0.19184536, -0.24934947],
#        [-0.1791165 , -0.47587636],
#        ...,
#        [ 0.89704016,  1.00334422],
#        [-0.45825611, -0.27426743],
#        [-0.22319117, -0.40338776]])

# %%
#updating the numerical(normalized) data into the dataframe
data_normalized=pd.DataFrame(data_normalized,columns=['FEB', 'MAR'])
data_normalized=data_normalized.join(data[data.columns.drop(['FEB', 'MAR'])])
data_normalized
# Out:
#           FEB       MAR                STATE_UT_NAME        DISTRICT  \
# 0    1.363497  0.806266  ANDAMAN And NICOBAR ISLANDS         NICOBAR
# 1    0.191845 -0.249349  ANDAMAN And NICOBAR ISLANDS   SOUTH ANDAMAN
# 2   -0.179116 -0.475876  ANDAMAN And NICOBAR ISLANDS   N & M ANDAMAN
# 3    2.204589  3.325245            ARUNACHAL PRADESH           LOHIT
# 4    2.156841  1.728230            ARUNACHAL PRADESH      EAST SIANG
# ..        ...       ...                          ...             ...
# 636  0.048603  0.316968                       KERALA          IDUKKI
# 637 -0.726377 -0.480407                       KERALA        KASARGOD
# 638  0.897040  1.003344                       KERALA  PATHANAMTHITTA
# 639 -0.458256 -0.274267                       KERALA         WAYANAD
# 640 -0.223191 -0.403388                  LAKSHADWEEP     LAKSHADWEEP
#
#             JAN    APR    MAY    JUN     JUL    AUG    SEP    OCT    NOV  \
# ...

# %% [markdown]
# # BOXPLOT

# %%
plt.boxplot(data['JAN'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20b3b705310>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x20b3b7058b0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x20b3b705040>],
#  'medians': [<matplotlib.lines.Line2D at 0x20b3b705e50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20b3b712160>],
#  'means': []}

# %% [markdown]
# # ENCODING

# %% [markdown]
# # REMOVE OUTLIER

# %%
lowerlimit=data['JAN'].quantile(0.05)
lowerlimit
# Out:
# 1.0

# %%
upperlimit=data['JAN'].quantile(0.95)
upperlimit
# Out:
# 61.6

# %%
data=data[(data['JAN']>lowerlimit)& (data['JAN']<upperlimit)]
data
# Out:
#                    STATE_UT_NAME        DISTRICT        JAN   FEB    MAR  \
# 1    ANDAMAN And NICOBAR ISLANDS   SOUTH ANDAMAN  18.315469  26.0   18.6
# 2    ANDAMAN And NICOBAR ISLANDS   N & M ANDAMAN  32.700000  15.9    8.6
# 3              ARUNACHAL PRADESH           LOHIT  42.200000  80.8  176.4
# 4              ARUNACHAL PRADESH      EAST SIANG  33.300000  79.5  105.9
# 5              ARUNACHAL PRADESH   SUBANSIRI F.D  28.000000  48.3   85.3
# ..                           ...             ...        ...   ...    ...
# 636                       KERALA          IDUKKI  13.400000  22.1   43.6
# 637                       KERALA        KASARGOD   2.300000   1.0    8.4
# 638                       KERALA  PATHANAMTHITTA  19.800000  45.2   73.9
# 639                       KERALA         WAYANAD   4.800000   8.3   17.5
# 640                  LAKSHADWEEP     LAKSHADWEEP  20.800000  14.7   11.8
#
#        APR    MAY    JUN     JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  \
# ...

# %%
data.drop(upperlimit[0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 data.drop(upperlimit[0])
#
# IndexError: invalid index to scalar variable.

# %%
plt.boxplot(data['JAN'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x214b7808b20>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x214b7817100>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x214b77f8850>],
#  'medians': [<matplotlib.lines.Line2D at 0x214b78176a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x214b7817970>],
#  'means': []}

# %% [markdown]
# # HIST

# %%
plt.hist(data['FEB'])
# Out:
# (array([475.,  99.,  32.,  13.,   9.,   4.,   2.,   4.,   1.,   1.]),
#  array([  0.  ,  22.96,  45.92,  68.88,  91.84, 114.8 , 137.76, 160.72,
#         183.68, 206.64, 229.6 ]),
#  <BarContainer object of 10 artists>)

# %%
# encoding categorical values
cat_features = ["JAN","FEB"]
data = pd.get_dummies(data_df,columns=cat_features)
print(data.columns)2
# Out:
# Index(['STATE_UT_NAME', 'DISTRICT', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG',
#        'SEP', 'OCT', 'NOV', 'DEC', 'ANNUAL', 'Jan-Feb', 'Mar-May', 'Jun-Sep',
#        'Oct-Dec'],
#       dtype='object')
