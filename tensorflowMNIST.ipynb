# %%
import tensorflow as tf

# %%
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),
  tf.keras.layers.Dense(512, activation='relu'),
  tf.keras.layers.Dense(512, activation='relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(512, activation='relu'),
  tf.keras.layers.Dense(10, activation='softmax')
 
])

# %%
model.compile(optimizer='SGD',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
tf_callbacks = tf.keras.callbacks.TensorBoard(log_dir = "logs/fit" , histogram_freq = 1)

# %%
history=model.fit(x_train, y_train,validation_data=(x_test,y_test), epochs=10, callbacks = tf_callbacks)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 20s 10ms/step - loss: 0.6135 - accuracy: 0.8369 - val_loss: 0.2932 - val_accuracy: 0.9137
# Epoch 2/10
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.2648 - accuracy: 0.9231 - val_loss: 0.2064 - val_accuracy: 0.9394
# Epoch 3/10
# 1875/1875 [==============================] - 16s 8ms/step - loss: 0.2045 - accuracy: 0.9407 - val_loss: 0.1665 - val_accuracy: 0.9500
# Epoch 4/10
# 1875/1875 [==============================] - 16s 8ms/step - loss: 0.1681 - accuracy: 0.9511 - val_loss: 0.1429 - val_accuracy: 0.9578
# Epoch 5/10
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.1429 - accuracy: 0.9584 - val_loss: 0.1250 - val_accuracy: 0.9619
# Epoch 6/10
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.1226 - accuracy: 0.9643 - val_loss: 0.1162 - val_accuracy: 0.9649
# Epoch 7/10
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.1086 - accuracy: 0.9681 - val_loss: 0.1034 - val_accuracy: 0.9683
# Epoch 8/10
# 1875/1875 [==============================] - 16s 9ms/step - loss: 0.0966 - accuracy: 0.9714 - val_loss: 0.0960 - val_accuracy: 0.9707
# Epoch 9/10
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.0854 - accuracy: 0.9756 - val_loss: 0.0911 - val_accuracy: 0.9704
# Epoch 10/10
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.0783 - accuracy: 0.9766 - val_loss: 0.0867 - val_accuracy: 0.9724

# %%
# %load_ext tensorboard

# %%
tensorboard --logdir logs/fit

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
